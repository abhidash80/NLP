# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: click in /Users/abhijitdash/.pyenv/versions/3.9.2/lib/python3.9/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /Users/abhijitdash/.pyenv/versions/3.9.2/lib/python3.9/site-packages (from nltk) (1.5.3)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2026.1.15-cp39-cp39-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting tqdm (from nltk)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 24.5 MB/s  0:00:00
# Downloading regex-2026.1.15-cp39-cp39-macosx_11_0_arm64.whl (288 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, nltk
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [nltk]━━━━━━━━━━━━━ 2/3 [nltk]
# Successfully installed nltk-3.9.2 regex-2026.1.15 tqdm-4.67.3
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
corpus="""LETS START TOKENIZATION TOPIC.
I will cover each topic! to be an expert.
"""

# %%
print(corpus)
# Out:
# LETS START TOKENIZATION TOPIC !.
# I will cover each topic to be an expert.

# %%
##Tokenization
##SENTENCE -->> paragraphs
from nltk.tokenize import sent_tokenize

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/abhijitdash/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/abhijitdash/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
documents=sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# LETS START TOKENIZATION TOPIC.
# I will cover each topic to be an expert.

# %%
##Tokenization
##Paragraph-->> words
##Sentence--->> words
from nltk.tokenize import word_tokenize

from nltk.tokenize import wordpunct_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['LETS',
#  'START',
#  'TOKENIZATION',
#  'TOPIC',
#  '.',
#  'I',
#  'will',
#  'cover',
#  'each',
#  'topic',
#  'to',
#  'be',
#  'an',
#  'expert',
#  '.']

# %%
for sentence in documents:
    print(wordpunct_tokenize(sentence))
# Out:
# ['LETS', 'START', 'TOKENIZATION', 'TOPIC', '!.']
# ['I', 'will', 'cover', 'each', 'topic', 'to', 'be', 'an', 'expert', '.']

# %% [raw]
# from nltk.tokenize import TreebankWordTokenizer

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['LETS',
#  'START',
#  'TOKENIZATION',
#  'TOPIC.',
#  'I',
#  'will',
#  'cover',
#  'each',
#  'topic',
#  '!',
#  'to',
#  'be',
#  'an',
#  'expert',
#  '.']
